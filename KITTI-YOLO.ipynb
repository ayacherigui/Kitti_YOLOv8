# %%
from ultralytics import YOLO

# %%
# CUDA_LAUNCH_BLOCKING=1

# %%
model = YOLO('yolov8n.pt')
 
# Training.
results = model.train(
   data='data_configs/data.yaml',
   imgsz=384,
   epochs=100,
   batch=16,
   name='yolov8n_custom')
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.6 torch-1.12.0+cu102 CUDA:0 (NVIDIA GeForce GTX 1080 Ti, 11179MiB)
# ...

# %%
# !yolo task=detect mode=val model="/home/aya/Desktop/Kitti_YOLOv8/runs/detect/best.pt" data=data.yaml
# Out:
# Traceback (most recent call last):
#   File "/home/aya/.local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/home/aya/.local/lib/python3.10/site-packages/ultralytics/yolo/cfg/__init__.py", line 230, in entrypoint
#     model = YOLO(model)
#   File "/home/aya/.local/lib/python3.10/site-packages/ultralytics/yolo/engine/model.py", line 60, in __init__
#     {'.pt': self._load, '.yaml': self._new}[suffix](model)
#   File "/home/aya/.local/lib/python3.10/site-packages/ultralytics/yolo/engine/model.py", line 90, in _load
#     self.model, self.ckpt = attempt_load_one_weight(weights)
#   File "/home/aya/.local/lib/python3.10/site-packages/ultralytics/nn/tasks.py", line 384, in attempt_load_one_weight
#     ckpt = torch_safe_load(weight)  # load ckpt
#   File "/home/aya/.local/lib/python3.10/site-packages/ultralytics/nn/tasks.py", line 332, in torch_safe_load
#     return torch.load(file, map_location='cpu')  # load
# ...

# %%
#!yolo task=detect mode=val model="/runs/detect/yolov8n_custom6/weights/best.pt" data=data.yaml
results = model.val()  # evaluate model performance on the test set
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.6 torch-1.12.0+cu102 CUDA:0 (NVIDIA GeForce GTX 1080 Ti, 11179MiB)
# Model summary (fused): 168 layers, 3007403 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /home/aya/Desktop/Kitti_YOLOv8/datasets/valid/labels.cache... 1122 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1122/1122 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 71/71 [00:07<00:00,  9.81it/s]
#                    all       1122       7724      0.735      0.631      0.682      0.448
#                Cyclist       1122        235      0.778        0.6      0.674      0.395
#               DontCare       1122       1690      0.443     0.0817      0.139     0.0403
#                   Misc       1122        113      0.757       0.58      0.623      0.409
#         Person_sitting       1122         47      0.605      0.488      0.532       0.27
# ...

# %%
#Before yolo
# !yolo task=detect mode=predict model=yolov8n.pt source="kitty/test/images/000036_png.rf.04ff80c138765044b69cb8df5d4078f4.jpg" save=True conf=0.5
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.6 torch-1.12.0+cu102 CUDA:0 (NVIDIA GeForce GTX 1080 Ti, 11169MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
# Traceback (most recent call last):
#   File "/home/aya/.local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/home/aya/.local/lib/python3.10/site-packages/ultralytics/yolo/cfg/__init__.py", line 249, in entrypoint
#     getattr(model, mode)(verbose=True, **overrides)
#   File "/home/aya/.local/lib/python3.10/site-packages/torch/autograd/grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
#   File "/home/aya/.local/lib/python3.10/site-packages/ultralytics/yolo/engine/model.py", line 146, in predict
#     return self.predictor(source=source, stream=stream, verbose=verbose)
#   File "/home/aya/.local/lib/python3.10/site-packages/torch/autograd/grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
# ...

# %%
#Try yolov8 on images
# !yolo task=detect mode=predict model=best.pt source="/home/aya/Desktop/Kitti_YOLOv8/datasets/train/images/000020.png" save=True conf=0.5
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.6 torch-1.12.0+cu102 CUDA:0 (NVIDIA GeForce GTX 1080 Ti, 11169MiB)
# Model summary (fused): 168 layers, 3008573 parameters, 0 gradients, 8.1 GFLOPs
# image 1/1 /home/aya/Desktop/Kitti_YOLOv8/datasets/train/images/000020.png: 128x384 1 car, 5.1ms
# Speed: 0.3ms pre-process, 5.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 384)
# Results saved to runs/detect/predict

# %%
# model = YOLO('/home/aya/Desktop/Kitti-ObjectDetection/runs/detect/yolov8n_custom/weights/best.pt')
# # Export the model in onnx format
# model.export(format='onnx')
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.6 torch-1.13.1+cu117 CUDA:0 (NVIDIA GeForce GTX 1080 Ti, 11169MiB)
# Model summary (fused): 168 layers, 3007403 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from /home/aya/Desktop/Kitti-ObjectDetection/runs/detect/yolov8n_custom15/weights/best.pt with output shape (1, 13, 31941) (6.0 MB)
#
# ONNX: starting export with onnx 1.13.1...
# ONNX: export success ✅ 0.5s, saved as /home/aya/Desktop/Kitti-ObjectDetection/runs/detect/yolov8n_custom15/weights/best.onnx (12.1 MB)
#
# Export complete (5.9s)
# Results saved to /home/aya/Desktop/Kitti-ObjectDetection/runs/detect/yolov8n_custom15/weights
# Predict:         yolo task=detect mode=predict model=/home/aya/Desktop/Kitti-ObjectDetection/runs/detect/yolov8n_custom15/weights/best.onnx -WARNING ⚠️ not yet supported for YOLOv8 exported models
# ...
